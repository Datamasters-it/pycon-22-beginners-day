# %%
import csv

# %% [markdown]
# ### Lettura del dataset

# %%
columns = []
pokemon_dataset = []
with open('pokemon.csv') as file:
    print(type(file))
    reader = csv.reader(file)
    columns = next(reader)
    for row in reader:
        pokemon_dataset.append(row)
# Out:
# <class '_io.TextIOWrapper'>

# %% [markdown]
# ### Elenco dei Pokemon con nome e generazione

# %%
for i in pokemon_dataset:
    print(f"{i[0]} - {i[1]} (gen. {i[11]})")
# Out:
# 1 - Bulbasaur (gen. 1)
# 2 - Ivysaur (gen. 1)
# 3 - Venusaur (gen. 1)
# 3 - VenusaurMega Venusaur (gen. 1)
# 4 - Charmander (gen. 1)
# 5 - Charmeleon (gen. 1)
# 6 - Charizard (gen. 1)
# 6 - CharizardMega Charizard X (gen. 1)
# 6 - CharizardMega Charizard Y (gen. 1)
# 7 - Squirtle (gen. 1)
# 8 - Wartortle (gen. 1)
# 9 - Blastoise (gen. 1)
# 9 - BlastoiseMega Blastoise (gen. 1)
# 10 - Caterpie (gen. 1)
# 11 - Metapod (gen. 1)
# 12 - Butterfree (gen. 1)
# 13 - Weedle (gen. 1)
# 14 - Kakuna (gen. 1)
# 15 - Beedrill (gen. 1)
# 15 - BeedrillMega Beedrill (gen. 1)
# 16 - Pidgey (gen. 1)
# 17 - Pidgeotto (gen. 1)
# 18 - Pidgeot (gen. 1)
# 18 - PidgeotMega Pidgeot (gen. 1)
# 19 - Rattata (gen. 1)
# 20 - Raticate (gen. 1)
# 21 - Spearow (gen. 1)
# 22 - Fearow (gen. 1)
# 23 - Ekans (gen. 1)
# 24 - Arbok (gen. 1)
# 25 - Pikachu (gen. 1)
# 26 - Raichu (gen. 1)
# 27 - Sandshrew (gen. 1)
# 28 - Sandslash (gen. 1)
# 29 - Nidoran♀ (gen. 1)
# 30 - Nidorina (gen. 1)
# 31 - Nidoqueen (gen. 1)
# 32 - Nidoran♂ (gen. 1)
# 33 - Nidorino (gen. 1)
# 34 - Nidoking (gen. 1)
# 35 - Clefairy (gen. 1)
# 36 - Clefable (gen. 1)
# 37 - Vulpix (gen. 1)
# 38 - Ninetales (gen. 1)
# 39 - Jigglypuff (gen. 1)
# 40 - Wigglytuff (gen. 1)
# 41 - Zubat (gen. 1)
# 42 - Golbat (gen. 1)
# 43 - Oddish (gen. 1)
# 44 - Gloom (gen. 1)
# 45 - Vileplume (gen. 1)
# 46 - Paras (gen. 1)
# 47 - Parasect (gen. 1)
# 48 - Venonat (gen. 1)
# 49 - Venomoth (gen. 1)
# 50 - Diglett (gen. 1)
# 51 - Dugtrio (gen. 1)
# 52 - Meowth (gen. 1)
# 53 - Persian (gen. 1)
# 54 - Psyduck (gen. 1)
# 55 - Golduck (gen. 1)
# 56 - Mankey (gen. 1)
# 57 - Primeape (gen. 1)
# 58 - Growlithe (gen. 1)
# 59 - Arcanine (gen. 1)
# 60 - Poliwag (gen. 1)
# 61 - Poliwhirl (gen. 1)
# 62 - Poliwrath (gen. 1)
# 63 - Abra (gen. 1)
# 64 - Kadabra (gen. 1)
# 65 - Alakazam (gen. 1)
# 65 - AlakazamMega Alakazam (gen. 1)
# 66 - Machop (gen. 1)
# 67 - Machoke (gen. 1)
# 68 - Machamp (gen. 1)
# 69 - Bellsprout (gen. 1)
# 70 - Weepinbell (gen. 1)
# 71 - Victreebel (gen. 1)
# 72 - Tentacool (gen. 1)
# 73 - Tentacruel (gen. 1)
# 74 - Geodude (gen. 1)
# 75 - Graveler (gen. 1)
# 76 - Golem (gen. 1)
# 77 - Ponyta (gen. 1)
# 78 - Rapidash (gen. 1)
# 79 - Slowpoke (gen. 1)
# 80 - Slowbro (gen. 1)
# 80 - SlowbroMega Slowbro (gen. 1)
# 81 - Magnemite (gen. 1)
# 82 - Magneton (gen. 1)
# 83 - Farfetch'd (gen. 1)
# 84 - Doduo (gen. 1)
# 85 - Dodrio (gen. 1)
# 86 - Seel (gen. 1)
# 87 - Dewgong (gen. 1)
# 88 - Grimer (gen. 1)
# 89 - Muk (gen. 1)
# 90 - Shellder (gen. 1)
# 91 - Cloyster (gen. 1)
# 92 - Gastly (gen. 1)
# 93 - Haunter (gen. 1)
# 94 - Gengar (gen. 1)
# 94 - GengarMega Gengar (gen. 1)
# 95 - Onix (gen. 1)
# 96 - Drowzee (gen. 1)
# 97 - Hypno (gen. 1)
# 98 - Krabby (gen. 1)
# 99 - Kingler (gen. 1)
# 100 - Voltorb (gen. 1)
# 101 - Electrode (gen. 1)
# 102 - Exeggcute (gen. 1)
# 103 - Exeggutor (gen. 1)
# 104 - Cubone (gen. 1)
# 105 - Marowak (gen. 1)
# 106 - Hitmonlee (gen. 1)
# 107 - Hitmonchan (gen. 1)
# 108 - Lickitung (gen. 1)
# 109 - Koffing (gen. 1)
# 110 - Weezing (gen. 1)
# 111 - Rhyhorn (gen. 1)
# 112 - Rhydon (gen. 1)
# 113 - Chansey (gen. 1)
# 114 - Tangela (gen. 1)
# 115 - Kangaskhan (gen. 1)
# 115 - KangaskhanMega Kangaskhan (gen. 1)
# 116 - Horsea (gen. 1)
# 117 - Seadra (gen. 1)
# 118 - Goldeen (gen. 1)
# 119 - Seaking (gen. 1)
# 120 - Staryu (gen. 1)
# 121 - Starmie (gen. 1)
# 122 - Mr. Mime (gen. 1)
# 123 - Scyther (gen. 1)
# 124 - Jynx (gen. 1)
# 125 - Electabuzz (gen. 1)
# 126 - Magmar (gen. 1)
# 127 - Pinsir (gen. 1)
# 127 - PinsirMega Pinsir (gen. 1)
# 128 - Tauros (gen. 1)
# 129 - Magikarp (gen. 1)
# 130 - Gyarados (gen. 1)
# 130 - GyaradosMega Gyarados (gen. 1)
# 131 - Lapras (gen. 1)
# 132 - Ditto (gen. 1)
# 133 - Eevee (gen. 1)
# 134 - Vaporeon (gen. 1)
# 135 - Jolteon (gen. 1)
# 136 - Flareon (gen. 1)
# 137 - Porygon (gen. 1)
# 138 - Omanyte (gen. 1)
# 139 - Omastar (gen. 1)
# 140 - Kabuto (gen. 1)
# 141 - Kabutops (gen. 1)
# 142 - Aerodactyl (gen. 1)
# 142 - AerodactylMega Aerodactyl (gen. 1)
# 143 - Snorlax (gen. 1)
# 144 - Articuno (gen. 1)
# 145 - Zapdos (gen. 1)
# 146 - Moltres (gen. 1)
# 147 - Dratini (gen. 1)
# 148 - Dragonair (gen. 1)
# 149 - Dragonite (gen. 1)
# 150 - Mewtwo (gen. 1)
# 150 - MewtwoMega Mewtwo X (gen. 1)
# 150 - MewtwoMega Mewtwo Y (gen. 1)
# 151 - Mew (gen. 1)
# 152 - Chikorita (gen. 2)
# 153 - Bayleef (gen. 2)
# 154 - Meganium (gen. 2)
# 155 - Cyndaquil (gen. 2)
# 156 - Quilava (gen. 2)
# 157 - Typhlosion (gen. 2)
# 158 - Totodile (gen. 2)
# 159 - Croconaw (gen. 2)
# 160 - Feraligatr (gen. 2)
# 161 - Sentret (gen. 2)
# 162 - Furret (gen. 2)
# 163 - Hoothoot (gen. 2)
# 164 - Noctowl (gen. 2)
# 165 - Ledyba (gen. 2)
# 166 - Ledian (gen. 2)
# 167 - Spinarak (gen. 2)
# 168 - Ariados (gen. 2)
# 169 - Crobat (gen. 2)
# 170 - Chinchou (gen. 2)
# 171 - Lanturn (gen. 2)
# 172 - Pichu (gen. 2)
# 173 - Cleffa (gen. 2)
# 174 - Igglybuff (gen. 2)
# 175 - Togepi (gen. 2)
# 176 - Togetic (gen. 2)
# 177 - Natu (gen. 2)
# 178 - Xatu (gen. 2)
# 179 - Mareep (gen. 2)
# 180 - Flaaffy (gen. 2)
# 181 - Ampharos (gen. 2)
# 181 - AmpharosMega Ampharos (gen. 2)
# 182 - Bellossom (gen. 2)
# 183 - Marill (gen. 2)
# 184 - Azumarill (gen. 2)
# 185 - Sudowoodo (gen. 2)
# 186 - Politoed (gen. 2)
# 187 - Hoppip (gen. 2)
# 188 - Skiploom (gen. 2)
# 189 - Jumpluff (gen. 2)
# 190 - Aipom (gen. 2)
# 191 - Sunkern (gen. 2)
# 192 - Sunflora (gen. 2)
# 193 - Yanma (gen. 2)
# 194 - Wooper (gen. 2)
# 195 - Quagsire (gen. 2)
# 196 - Espeon (gen. 2)
# 197 - Umbreon (gen. 2)
# 198 - Murkrow (gen. 2)
# 199 - Slowking (gen. 2)
# 200 - Misdreavus (gen. 2)
# 201 - Unown (gen. 2)
# 202 - Wobbuffet (gen. 2)
# 203 - Girafarig (gen. 2)
# 204 - Pineco (gen. 2)
# 205 - Forretress (gen. 2)
# 206 - Dunsparce (gen. 2)
# 207 - Gligar (gen. 2)
# 208 - Steelix (gen. 2)
# 208 - SteelixMega Steelix (gen. 2)
# 209 - Snubbull (gen. 2)
# 210 - Granbull (gen. 2)
# 211 - Qwilfish (gen. 2)
# 212 - Scizor (gen. 2)
# 212 - ScizorMega Scizor (gen. 2)
# 213 - Shuckle (gen. 2)
# 214 - Heracross (gen. 2)
# 214 - HeracrossMega Heracross (gen. 2)
# 215 - Sneasel (gen. 2)
# 216 - Teddiursa (gen. 2)
# 217 - Ursaring (gen. 2)
# 218 - Slugma (gen. 2)
# 219 - Magcargo (gen. 2)
# 220 - Swinub (gen. 2)
# 221 - Piloswine (gen. 2)
# 222 - Corsola (gen. 2)
# 223 - Remoraid (gen. 2)
# 224 - Octillery (gen. 2)
# 225 - Delibird (gen. 2)
# 226 - Mantine (gen. 2)
# 227 - Skarmory (gen. 2)
# 228 - Houndour (gen. 2)
# 229 - Houndoom (gen. 2)
# 229 - HoundoomMega Houndoom (gen. 2)
# 230 - Kingdra (gen. 2)
# 231 - Phanpy (gen. 2)
# 232 - Donphan (gen. 2)
# 233 - Porygon2 (gen. 2)
# 234 - Stantler (gen. 2)
# 235 - Smeargle (gen. 2)
# 236 - Tyrogue (gen. 2)
# 237 - Hitmontop (gen. 2)
# 238 - Smoochum (gen. 2)
# 239 - Elekid (gen. 2)
# 240 - Magby (gen. 2)
# 241 - Miltank (gen. 2)
# 242 - Blissey (gen. 2)
# 243 - Raikou (gen. 2)
# 244 - Entei (gen. 2)
# 245 - Suicune (gen. 2)
# 246 - Larvitar (gen. 2)
# 247 - Pupitar (gen. 2)
# 248 - Tyranitar (gen. 2)
# 248 - TyranitarMega Tyranitar (gen. 2)
# 249 - Lugia (gen. 2)
# 250 - Ho-oh (gen. 2)
# 251 - Celebi (gen. 2)
# 252 - Treecko (gen. 3)
# 253 - Grovyle (gen. 3)
# 254 - Sceptile (gen. 3)
# 254 - SceptileMega Sceptile (gen. 3)
# 255 - Torchic (gen. 3)
# 256 - Combusken (gen. 3)
# 257 - Blaziken (gen. 3)
# 257 - BlazikenMega Blaziken (gen. 3)
# 258 - Mudkip (gen. 3)
# 259 - Marshtomp (gen. 3)
# 260 - Swampert (gen. 3)
# 260 - SwampertMega Swampert (gen. 3)
# 261 - Poochyena (gen. 3)
# 262 - Mightyena (gen. 3)
# 263 - Zigzagoon (gen. 3)
# 264 - Linoone (gen. 3)
# 265 - Wurmple (gen. 3)
# 266 - Silcoon (gen. 3)
# 267 - Beautifly (gen. 3)
# 268 - Cascoon (gen. 3)
# 269 - Dustox (gen. 3)
# 270 - Lotad (gen. 3)
# 271 - Lombre (gen. 3)
# 272 - Ludicolo (gen. 3)
# 273 - Seedot (gen. 3)
# 274 - Nuzleaf (gen. 3)
# 275 - Shiftry (gen. 3)
# 276 - Taillow (gen. 3)
# 277 - Swellow (gen. 3)
# 278 - Wingull (gen. 3)
# 279 - Pelipper (gen. 3)
# 280 - Ralts (gen. 3)
# 281 - Kirlia (gen. 3)
# 282 - Gardevoir (gen. 3)
# 282 - GardevoirMega Gardevoir (gen. 3)
# 283 - Surskit (gen. 3)
# 284 - Masquerain (gen. 3)
# 285 - Shroomish (gen. 3)
# 286 - Breloom (gen. 3)
# 287 - Slakoth (gen. 3)
# 288 - Vigoroth (gen. 3)
# 289 - Slaking (gen. 3)
# 290 - Nincada (gen. 3)
# 429 - Mismagius (gen. 4)
# 430 - Honchkrow (gen. 4)
# 431 - Glameow (gen. 4)
# 432 - Purugly (gen. 4)
# 433 - Chingling (gen. 4)
# 434 - Stunky (gen. 4)
# 435 - Skuntank (gen. 4)
# 436 - Bronzor (gen. 4)
# 437 - Bronzong (gen. 4)
# 438 - Bonsly (gen. 4)
# 439 - Mime Jr. (gen. 4)
# 440 - Happiny (gen. 4)
# 441 - Chatot (gen. 4)
# 442 - Spiritomb (gen. 4)
# 443 - Gible (gen. 4)
# 444 - Gabite (gen. 4)
# 445 - Garchomp (gen. 4)
# 445 - GarchompMega Garchomp (gen. 4)
# 446 - Munchlax (gen. 4)
# 447 - Riolu (gen. 4)
# 448 - Lucario (gen. 4)
# 448 - LucarioMega Lucario (gen. 4)
# 449 - Hippopotas (gen. 4)
# 450 - Hippowdon (gen. 4)
# 451 - Skorupi (gen. 4)
# 452 - Drapion (gen. 4)
# 453 - Croagunk (gen. 4)
# 454 - Toxicroak (gen. 4)
# 455 - Carnivine (gen. 4)
# 456 - Finneon (gen. 4)
# 457 - Lumineon (gen. 4)
# 458 - Mantyke (gen. 4)
# 459 - Snover (gen. 4)
# 460 - Abomasnow (gen. 4)
# 460 - AbomasnowMega Abomasnow (gen. 4)
# 461 - Weavile (gen. 4)
# 462 - Magnezone (gen. 4)
# 463 - Lickilicky (gen. 4)
# 464 - Rhyperior (gen. 4)
# 465 - Tangrowth (gen. 4)
# 466 - Electivire (gen. 4)
# 467 - Magmortar (gen. 4)
# 468 - Togekiss (gen. 4)
# 469 - Yanmega (gen. 4)
# 470 - Leafeon (gen. 4)
# 471 - Glaceon (gen. 4)
# 472 - Gliscor (gen. 4)
# 473 - Mamoswine (gen. 4)
# 474 - Porygon-Z (gen. 4)
# 475 - Gallade (gen. 4)
# 475 - GalladeMega Gallade (gen. 4)
# 476 - Probopass (gen. 4)
# 477 - Dusknoir (gen. 4)
# 478 - Froslass (gen. 4)
# 479 - Rotom (gen. 4)
# 479 - RotomHeat Rotom (gen. 4)
# 479 - RotomWash Rotom (gen. 4)
# 479 - RotomFrost Rotom (gen. 4)
# 479 - RotomFan Rotom (gen. 4)
# 479 - RotomMow Rotom (gen. 4)
# 480 - Uxie (gen. 4)
# 481 - Mesprit (gen. 4)
# 482 - Azelf (gen. 4)
# 483 - Dialga (gen. 4)
# 484 - Palkia (gen. 4)
# 485 - Heatran (gen. 4)
# 486 - Regigigas (gen. 4)
# 487 - GiratinaAltered Forme (gen. 4)
# 487 - GiratinaOrigin Forme (gen. 4)
# 488 - Cresselia (gen. 4)
# 489 - Phione (gen. 4)
# 490 - Manaphy (gen. 4)
# 491 - Darkrai (gen. 4)
# 492 - ShayminLand Forme (gen. 4)
# 492 - ShayminSky Forme (gen. 4)
# 493 - Arceus (gen. 4)
# 494 - Victini (gen. 5)
# 495 - Snivy (gen. 5)
# 496 - Servine (gen. 5)
# 497 - Serperior (gen. 5)
# 498 - Tepig (gen. 5)
# 499 - Pignite (gen. 5)
# 500 - Emboar (gen. 5)
# 501 - Oshawott (gen. 5)
# 502 - Dewott (gen. 5)
# 503 - Samurott (gen. 5)
# 504 - Patrat (gen. 5)
# 505 - Watchog (gen. 5)
# 506 - Lillipup (gen. 5)
# 507 - Herdier (gen. 5)
# 508 - Stoutland (gen. 5)
# 509 - Purrloin (gen. 5)
# 510 - Liepard (gen. 5)
# 511 - Pansage (gen. 5)
# 512 - Simisage (gen. 5)
# 513 - Pansear (gen. 5)
# 514 - Simisear (gen. 5)
# 515 - Panpour (gen. 5)
# 516 - Simipour (gen. 5)
# 517 - Munna (gen. 5)
# 518 - Musharna (gen. 5)
# 519 - Pidove (gen. 5)
# 520 - Tranquill (gen. 5)
# 521 - Unfezant (gen. 5)
# 522 - Blitzle (gen. 5)
# 523 - Zebstrika (gen. 5)
# 524 - Roggenrola (gen. 5)
# 525 - Boldore (gen. 5)
# 526 - Gigalith (gen. 5)
# 527 - Woobat (gen. 5)
# 528 - Swoobat (gen. 5)
# 529 - Drilbur (gen. 5)
# 530 - Excadrill (gen. 5)
# 531 - Audino (gen. 5)
# 531 - AudinoMega Audino (gen. 5)
# 532 - Timburr (gen. 5)
# 533 - Gurdurr (gen. 5)
# 534 - Conkeldurr (gen. 5)
# 535 - Tympole (gen. 5)
# 536 - Palpitoad (gen. 5)
# 537 - Seismitoad (gen. 5)
# 538 - Throh (gen. 5)
# 539 - Sawk (gen. 5)
# 540 - Sewaddle (gen. 5)
# 541 - Swadloon (gen. 5)
# 542 - Leavanny (gen. 5)
# 543 - Venipede (gen. 5)
# 544 - Whirlipede (gen. 5)
# 545 - Scolipede (gen. 5)
# 546 - Cottonee (gen. 5)
# 547 - Whimsicott (gen. 5)
# 548 - Petilil (gen. 5)
# 549 - Lilligant (gen. 5)
# 550 - Basculin (gen. 5)
# 551 - Sandile (gen. 5)
# 552 - Krokorok (gen. 5)
# 553 - Krookodile (gen. 5)
# 554 - Darumaka (gen. 5)
# 555 - DarmanitanStandard Mode (gen. 5)
# 555 - DarmanitanZen Mode (gen. 5)
# 556 - Maractus (gen. 5)
# 557 - Dwebble (gen. 5)
# 558 - Crustle (gen. 5)
# 559 - Scraggy (gen. 5)
# 560 - Scrafty (gen. 5)
# 561 - Sigilyph (gen. 5)
# 562 - Yamask (gen. 5)
# 563 - Cofagrigus (gen. 5)
# 564 - Tirtouga (gen. 5)
# 565 - Carracosta (gen. 5)
# 566 - Archen (gen. 5)
# 567 - Archeops (gen. 5)
# 568 - Trubbish (gen. 5)
# 569 - Garbodor (gen. 5)
# 570 - Zorua (gen. 5)
# 571 - Zoroark (gen. 5)
# 572 - Minccino (gen. 5)
# 573 - Cinccino (gen. 5)
# 574 - Gothita (gen. 5)
# 575 - Gothorita (gen. 5)
# 576 - Gothitelle (gen. 5)
# 577 - Solosis (gen. 5)
# 578 - Duosion (gen. 5)
# 579 - Reuniclus (gen. 5)
# 580 - Ducklett (gen. 5)
# 581 - Swanna (gen. 5)
# 582 - Vanillite (gen. 5)
# 583 - Vanillish (gen. 5)
# 584 - Vanilluxe (gen. 5)
# 585 - Deerling (gen. 5)
# 586 - Sawsbuck (gen. 5)
# 587 - Emolga (gen. 5)
# 588 - Karrablast (gen. 5)
# 589 - Escavalier (gen. 5)
# 590 - Foongus (gen. 5)
# 591 - Amoonguss (gen. 5)
# 592 - Frillish (gen. 5)
# 593 - Jellicent (gen. 5)
# 594 - Alomomola (gen. 5)
# 595 - Joltik (gen. 5)
# 596 - Galvantula (gen. 5)
# 597 - Ferroseed (gen. 5)
# 598 - Ferrothorn (gen. 5)
# 599 - Klink (gen. 5)
# 600 - Klang (gen. 5)
# 601 - Klinklang (gen. 5)
# 602 - Tynamo (gen. 5)
# 603 - Eelektrik (gen. 5)
# 604 - Eelektross (gen. 5)
# 605 - Elgyem (gen. 5)
# 606 - Beheeyem (gen. 5)
# 607 - Litwick (gen. 5)
# 608 - Lampent (gen. 5)
# 609 - Chandelure (gen. 5)
# 610 - Axew (gen. 5)
# 611 - Fraxure (gen. 5)
# 612 - Haxorus (gen. 5)
# 613 - Cubchoo (gen. 5)
# 614 - Beartic (gen. 5)
# 615 - Cryogonal (gen. 5)
# 616 - Shelmet (gen. 5)
# 617 - Accelgor (gen. 5)
# 618 - Stunfisk (gen. 5)
# 619 - Mienfoo (gen. 5)
# 620 - Mienshao (gen. 5)
# 621 - Druddigon (gen. 5)
# 622 - Golett (gen. 5)
# 623 - Golurk (gen. 5)
# 624 - Pawniard (gen. 5)
# 625 - Bisharp (gen. 5)
# 626 - Bouffalant (gen. 5)
# 627 - Rufflet (gen. 5)
# 628 - Braviary (gen. 5)
# 629 - Vullaby (gen. 5)
# 630 - Mandibuzz (gen. 5)
# 631 - Heatmor (gen. 5)
# 632 - Durant (gen. 5)
# 633 - Deino (gen. 5)
# 634 - Zweilous (gen. 5)
# 635 - Hydreigon (gen. 5)
# 636 - Larvesta (gen. 5)
# 637 - Volcarona (gen. 5)
# 638 - Cobalion (gen. 5)
# 639 - Terrakion (gen. 5)
# 640 - Virizion (gen. 5)
# 641 - TornadusIncarnate Forme (gen. 5)
# 641 - TornadusTherian Forme (gen. 5)
# 642 - ThundurusIncarnate Forme (gen. 5)
# 642 - ThundurusTherian Forme (gen. 5)
# 643 - Reshiram (gen. 5)
# 644 - Zekrom (gen. 5)
# 645 - LandorusIncarnate Forme (gen. 5)
# 645 - LandorusTherian Forme (gen. 5)
# 646 - Kyurem (gen. 5)
# 646 - KyuremBlack Kyurem (gen. 5)
# 646 - KyuremWhite Kyurem (gen. 5)
# 647 - KeldeoOrdinary Forme (gen. 5)
# 647 - KeldeoResolute Forme (gen. 5)
# 648 - MeloettaAria Forme (gen. 5)
# 648 - MeloettaPirouette Forme (gen. 5)
# 649 - Genesect (gen. 5)
# 650 - Chespin (gen. 6)
# 651 - Quilladin (gen. 6)
# 652 - Chesnaught (gen. 6)
# ### Elenco dei campi disponibili per ogni pokemon

# %%
for k, v in zip(columns, pokemon_dataset[0]):
    print(f"{k:10} -> {v:15} ({type(v)})")
# Out:
# #          -> 1               (<class 'str'>)
# Name       -> Bulbasaur       (<class 'str'>)
# Type 1     -> Grass           (<class 'str'>)
# Type 2     -> Poison          (<class 'str'>)
# Total      -> 318             (<class 'str'>)
# HP         -> 45              (<class 'str'>)
# Attack     -> 49              (<class 'str'>)
# Defense    -> 49              (<class 'str'>)
# Sp. Atk    -> 65              (<class 'str'>)
# Sp. Def    -> 65              (<class 'str'>)
# Speed      -> 45              (<class 'str'>)
# Generation -> 1               (<class 'str'>)
# Legendary  -> False           (<class 'str'>)

# %% [markdown]
# Purtroppo tutti i campi sono letti come stringa. Dobbiamo convertire in numero le colonne da `HP` a `Speed`

# %%
num_indexes = [5, 6, 7, 8, 9, 10]

numerical_data = []
for i in range(len(pokemon_dataset)):
    row = pokemon_dataset[i]
    num_row = []
    for col in num_indexes:
        num_row.append(float(row[col]))

    numerical_data.append(num_row)

for k, v in zip(columns[5:11], numerical_data[0]):
    print(f"{k:10} -> {v:5} ({type(v)})")
# Out:
# HP         ->  45.0 (<class 'float'>)
# Attack     ->  49.0 (<class 'float'>)
# Defense    ->  49.0 (<class 'float'>)
# Sp. Atk    ->  65.0 (<class 'float'>)
# Sp. Def    ->  65.0 (<class 'float'>)
# Speed      ->  45.0 (<class 'float'>)

# %%
'''
Normalizzare significa scalare tutti i dati fra 0 e 1.
Prendiamo la prima entry del dataset e riga per riga/colonna per colonna
ci andiamo a costruire un elenco di valori per colonna:
es. dataset di partenza:
    [
        [20, 40, 50],
        [30, 10, 60],
        [50, 35, 70],
        [10, 11, 80],
    ]

    col_values:
        [ 20, 30, 50, 10 ],
        [ 40, 10, 35, 11 ],
        [ 50, 60, 70, 80 ]
    trovo min e max delle singole righe di col_values (i cui indici sono 
    gli indici delle colonne del dataset iniziale )

    colonna 0 -> (10, 50)
    colonna 1 -> (10, 40)
    colonna 2 -> (50, 80)

    quindi avremo: 
    [
        (10, 50),
        (10, 40),
        (50, 80),
    ]
'''

def normalize(dataset):
    output = []

    min_max = []

    for i in range(len(dataset[0])):
        # per ciascuna colonna:
            # prendiamo tutti i valori di quella colonna nel dataset
            # calcoliamo val. minimo e max della colonna
            # add della tupla min/max della colonna alla lista min_max
        col_values = [row[i] for row in dataset]
        min_max.append((min(col_values), max(col_values)))

    print(min_max)
    for row in dataset:
        scaled_row = []
        for col_index in range(len(row)):
            col_value = row[col_index]
            scaled_value = (col_value - min_max[col_index][0])/(min_max[col_index][1] - min_max[col_index][0])
            scaled_row.append(scaled_value)

        output.append(scaled_row)

    return output

# Calcola la distanza di minkowski fra 2 punti. 
# Si può semplificare andando a prendere direttamente la dist. euclidea e basta
def minkowski_distance(p1, p2, p = 2):
        # https://rittikghosh.com/images/min.png
        # p = 1 -> Manhattan Distance
        # p = 2 -> Euclidean Distance
        dim = len(p1)
        distance = 0
        for d in range(dim):
            distance += abs(p1[d] - p2[d]) ** p

        distance = distance**(1/p)

        return distance

'''
    Questa funzione ci restituisce una lista di lunghezza pari a K 
    contenente una serie di tuple in cui abbiamo:
        - indice i dell'elemento nel dataset
        - distanza della riga test_row dall'elemento con indice i
'''
def get_k_neighbors(k, dataset, test_row):
    dataset.append(test_row)
    norm_dataset = normalize(dataset)
    norm_test_row = norm_dataset[-1]
    norm_dataset = norm_dataset[:-1]

    distances = []

    for i in range(len(norm_dataset)):
        row = norm_dataset[i]
        d = minkowski_distance(norm_test_row, row)
        distances.append((i, d))


    distances.sort(key=lambda tup: tup[1])

    return distances[:k]

def print_pokemon_info(i):
    s = f"{pokemon_dataset[i][0]} - {pokemon_dataset[i][1]}, di tipo {pokemon_dataset[i][2]} (gen. {pokemon_dataset[i][-2]})"
    if pokemon_dataset[i][-1] == "True":
        s += f"\n - POKEMON LEGGENDARIO"

    for k in num_indexes:
        s += f"\n{columns[k]:20}: {pokemon_dataset[i][k]}"
    return s

# %% [markdown]
# Prendiamo in input i dati dell'utente (Questa si può migliorare)

# %%
user_row = []

k = 5

for i in range(len(num_indexes)):
    col_index = num_indexes[i]
    v = input(f"Inserisci il tuo valore di {columns[col_index]}\n")
    user_row.append(float(v))

for k, v in zip(columns[5:11], user_row):
    print(f"{k:10} -> {v:15} ({type(v)})")

print("Calcolo i tuoi pokemon più affini...")

l = get_k_neighbors(5, numerical_data, user_row)
print(l)

for p in l:
    print(print_pokemon_info(p[0]))
# Out:
# Inserisci il tuo valore di HP
# 100
# Inserisci il tuo valore di Attack
# 100
# Inserisci il tuo valore di Defense
# 100
# Inserisci il tuo valore di Sp. Atk
# 100
# Inserisci il tuo valore di Sp. Def
# 100
# Inserisci il tuo valore di Speed
# 100
# HP         ->           100.0 (<class 'float'>)
# Attack     ->           100.0 (<class 'float'>)
# Defense    ->           100.0 (<class 'float'>)
# Sp. Atk    ->           100.0 (<class 'float'>)
# Sp. Def    ->           100.0 (<class 'float'>)
# Speed      ->           100.0 (<class 'float'>)
# Calcolo i tuoi pokemon più affini...
# [(1.0, 255.0), (5.0, 190.0), (5.0, 230.0), (10.0, 194.0), (20.0, 230.0), (5.0, 180.0)]
# [(165, 0.0), (271, 0.0), (427, 0.0), (548, 0.0), (550, 0.0)]
# 151 - Mew, di tipo Psychic (gen. 1)
# HP                  : 100
# Attack              : 100
# Defense             : 100
# Sp. Atk             : 100
# Sp. Def             : 100
# Speed               : 100
# 251 - Celebi, di tipo Psychic (gen. 2)
# HP                  : 100
# Attack              : 100
# Defense             : 100
# Sp. Atk             : 100
# Sp. Def             : 100
# Speed               : 100
# 385 - Jirachi, di tipo Steel (gen. 3)
#  - POKEMON LEGGENDARIO
# HP                  : 100
# Attack              : 100
# Defense             : 100
# Sp. Atk             : 100
# Sp. Def             : 100
# Speed               : 100
# 490 - Manaphy, di tipo Water (gen. 4)
# HP                  : 100
# Attack              : 100
# Defense             : 100
# Sp. Atk             : 100
# Sp. Def             : 100
# Speed               : 100
# 492 - ShayminLand Forme, di tipo Grass (gen. 4)
#  - POKEMON LEGGENDARIO
# HP                  : 100
# Attack              : 100
# Defense             : 100
# Sp. Atk             : 100
# Sp. Def             : 100
# Speed               : 100

# %%
images_paths = [ f"sugimori/{pokemon_dataset[p[0]][0]}.png" for p in l ]
print(images_paths)
import ipyplot

ipyplot.plot_images(images_paths, labels=[ pokemon_dataset[p[0]][1] for p in l ], max_images=5, img_width=150)
# Out:
# ['sugimori/151.png', 'sugimori/251.png', 'sugimori/385.png', 'sugimori/490.png', 'sugimori/492.png']
#     <style>
#         #ipyplot-html-viewer-toggle-QmdkwwPdKJUkVhZ9KZruaK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-QmdkwwPdKJUkVhZ9KZruaK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-QmdkwwPdKJUkVhZ9KZruaK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-QmdkwwPdKJUkVhZ9KZruaK:checked ~ #ipyplot-html-viewer-textarea-QmdkwwPdKJUkVhZ9KZruaK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-QmdkwwPdKJUkVhZ9KZruaK:checked + #ipyplot-html-viewer-label-QmdkwwPdKJUkVhZ9KZruaK:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-QmdkwwPdKJUkVhZ9KZruaK">
#         <label id="ipyplot-html-viewer-label-QmdkwwPdKJUkVhZ9KZruaK" for="ipyplot-html-viewer-toggle-QmdkwwPdKJUkVhZ9KZruaK">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-QmdkwwPdKJUkVhZ9KZruaK" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gG9XDHQ3jQ3f4sog7br5L2">
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-gFMckXKa4A97XhNwMhwim4" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Mew</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/151.png</h4><img src="sugimori/151.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-gFMckXKa4A97XhNwMhwim4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-D3G2mW2qAEZazgmET3MRqK" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Celebi</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/251.png</h4><img src="sugimori/251.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-D3G2mW2qAEZazgmET3MRqK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7yjn4hyadjdVZBojHD2N5" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Jirachi</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/385.png</h4><img src="sugimori/385.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7yjn4hyadjdVZBojHD2N5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-dWKyDnraihm6HA9PiaYCfw" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Manaphy</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/490.png</h4><img src="sugimori/490.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-dWKyDnraihm6HA9PiaYCfw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7CDDRX4LnZJwDnBGZScYR" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ShayminLand Forme</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/492.png</h4><img src="sugimori/492.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7CDDRX4LnZJwDnBGZScYR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-gG9XDHQ3jQ3f4sog7br5L2">
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-gFMckXKa4A97XhNwMhwim4" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Mew</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/151.png</h4><img src="sugimori/151.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-gFMckXKa4A97XhNwMhwim4">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-D3G2mW2qAEZazgmET3MRqK" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Celebi</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/251.png</h4><img src="sugimori/251.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-D3G2mW2qAEZazgmET3MRqK">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7yjn4hyadjdVZBojHD2N5" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Jirachi</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/385.png</h4><img src="sugimori/385.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7yjn4hyadjdVZBojHD2N5">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-dWKyDnraihm6HA9PiaYCfw" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">Manaphy</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/490.png</h4><img src="sugimori/490.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-dWKyDnraihm6HA9PiaYCfw">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-gG9XDHQ3jQ3f4sog7br5L2">
#         <div id="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7CDDRX4LnZJwDnBGZScYR" class="ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">ShayminLand Forme</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">sugimori/492.png</h4><img src="sugimori/492.png"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-gG9XDHQ3jQ3f4sog7br5L2-S7CDDRX4LnZJwDnBGZScYR">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
